# %% [markdown]
# ## 1. Confirm the GPU

# %%
# !nvidia-smi
import torch
print('torch', torch.__version__, '| cuda available:', torch.cuda.is_available())
assert torch.cuda.is_available(), 'No GPU. Notebook settings (right panel) -> Accelerator -> GPU T4 x2'
# Out:
# Sun Sep 20 15:23:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# torch 2.10.0+cu128 | cuda available: True

# %% [markdown]
# ## 2. Locate the attached dataset
#
# Auto-detects the mounted dataset by looking for `Dataset/Img` under `/kaggle/input`, so you don't need to hardcode your dataset's slug.

# %%
import os

def find_input_root(target=os.path.join('Dataset', 'Img')):
    for root, dirs, files in os.walk('/kaggle/input/datasets/faiyazabrar/ocrd-mimosa'):
        if root.endswith(target):
            return os.path.dirname(os.path.dirname(root))  # strip 'Img', then 'Dataset'
    return None

INPUT_ROOT = find_input_root()
assert INPUT_ROOT, (
    'No Dataset/Img found anywhere under /kaggle/input. '
    'Run print(os.listdir("/kaggle/input/datasets")) to inspect the real layout.'
)
print('Dataset mount:', INPUT_ROOT)
print('memes    :', len(os.listdir(f'{INPUT_ROOT}/Dataset/Img')))
print(sorted(os.listdir(INPUT_ROOT)))
# Out:
# Dataset mount: /kaggle/input/datasets/faiyazabrar/ocrd-mimosa
# memes    : 4848
# ['Dataset', 'README.md', 'Scripts', 'requirements.txt']

# %% [markdown]
# ## 3. Install dependencies
#
# Kaggle notebooks already ship a CUDA build of torch, so only the extras are installed — notably CLIP from source, exactly as the original `requirements.txt` specifies.

# %%
# !pip install -q transformers sentencepiece imbalanced-learn madgrad ftfy regex
# !pip install -q git+https://github.com/openai/CLIP.git

import clip, transformers
print('transformers', transformers.__version__)
print('clip OK')
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
#   Building wheel for madgrad (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#   Building wheel for clip (setup.py) ... done
# transformers 5.0.0
# clip OK

# %% [markdown]
# ## 4. Set up a writable working copy
#
# `/kaggle/input` is read-only, but `main.py` needs to create `Saved_Models/`, `Outputs/` and a `.cache/` next to `Scripts/`. So `Scripts/` (a few hundred KB) is copied to `/kaggle/working`; `Dataset/` (365 MB of images) stays on the read-only input mount and is referenced by an absolute path — no need to duplicate it.

# %%
import shutil

ROOT = '/kaggle/working/Replication'
os.makedirs(ROOT, exist_ok=True)

if os.path.isdir(f'{ROOT}/Scripts'):
    shutil.rmtree(f'{ROOT}/Scripts')
shutil.copytree(f'{INPUT_ROOT}/Scripts', f'{ROOT}/Scripts')
shutil.copy(f'{INPUT_ROOT}/requirements.txt', ROOT)

DATASET_PATH = f'{INPUT_ROOT}/Dataset'  # absolute path -> main.py reads straight from the input mount
print('Working scripts at:', f'{ROOT}/Scripts')
print('Reading dataset from (read-only):', DATASET_PATH)
# Out:
# Working scripts at: /kaggle/working/Replication/Scripts
# Reading dataset from (read-only): /kaggle/input/datasets/faiyazabrar/ocrd-mimosa/Dataset

# %% [markdown]
# ## 5. Splits summary (cf. paper Table 1)

# %%
import pandas as pd
for name in ['training_set', 'validation_set', 'testing_set']:
    df = pd.read_csv(f'{DATASET_PATH}/{name}.csv')
    print(f'{name:<16} {len(df):>5} rows   ', dict(df["Label"].value_counts()))
# Out:
# training_set      3393 rows    {'non-aggressive': np.int64(846), 'gendered aggression': np.int64(672), 'others': np.int64(660), 'religious aggression': np.int64(618), 'political aggression': np.int64(597)}
# validation_set     727 rows    {'non-aggressive': np.int64(181), 'gendered aggression': np.int64(144), 'others': np.int64(141), 'religious aggression': np.int64(133), 'political aggression': np.int64(128)}
# testing_set        728 rows    {'non-aggressive': np.int64(182), 'gendered aggression': np.int64(144), 'others': np.int64(142), 'religious aggression': np.int64(132), 'political aggression': np.int64(128)}

# %% [markdown]
# ## 6. Smoke test
#
# Runs the full pipeline on a handful of memes for one epoch. This is **not a result** — it only proves the data, the model and the metrics all wire up before committing to a long run.

# %%
# %cd {ROOT}/Scripts
# !python main.py --dataset "{DATASET_PATH}" --subset 24 --n_iter 1 --run_name kaggle_smoketest
# Out:
# /kaggle/working/Replication/Scripts
# Device: cuda:0
# Fetching Dataset...
# -----------------------------
# Maximum Text Length:  70
# Batch Size:  4
# Classes: 5 ['NoAg', 'GAg', 'PAg', 'RAg', 'Oth']
# SUBSET MODE: 20 rows per split (smoke test, not a real result)
# Training Data: 20
# Valid Data: 20
# Test Data: 20
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100%|█████████████████████████████| 491/491 [00:00<00:00, 2.64MB/s]
# vocab.txt: 2.24MB [00:00, 116MB/s]
# Fetched.
# Time required for preparing the Data loaders: 1.82s
# --------------------------------
# Checkpoint file: /kaggle/working/Replication/Saved_Models/maf_model_kaggle_smoketest.pth
# 100%|████████████████████████████████████████| 338M/338M [00:01<00:00, 353MiB/s]
# model.safetensors: 100%|██████████████████████| 660M/660M [00:04<00:00, 164MB/s]
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1504.68it/s, Materializing param=
# BertModel LOAD REPORT from: sagorsarker/bangla-bert-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Start Training MAF
# --------------------------------
# Device: cuda:0
# Classes#: 5
# Attention Heads#: 16
# Attention variant: code
# Epochs#: 1
# Learning Rate: 5e-05
# --------------------------------
# Epoch 1/1: 100%|██████████| 5/5 [00:02<00:00,  1.95batch/s, acc=0.05, loss=1.65]
# Validation: 100%|██████████████████████████████| 5/5 [00:00<00:00,  8.39batch/s]
# Epoch 1/1, Train Loss: 1.6533, Train Acc: 5.00%, Val Acc: 25.00%
# Model Saved.
# Best Validation Accuracy: 25.00%
# --------------------------------
# Model is Loading.. maf_model_kaggle_smoketest.pth
# Loaded.
# --------------------------------
# Start Evaluating..
# Testing: 100%|█████████████████████████████████| 5/5 [00:00<00:00,  7.02batch/s]
# Evaluation Done.
# --------------------------------
# Classification Report :
#               precision    recall  f1-score   support
#
#         NoAg      0.000     0.000     0.000         4
#          GAg      0.235     1.000     0.381         4
#          PAg      0.000     0.000     0.000         4
#          RAg      0.000     0.000     0.000         4
#          Oth      0.000     0.000     0.000         4
#
#     accuracy                          0.200        20
#    macro avg      0.047     0.200     0.076        20
# weighted avg      0.047     0.200     0.076        20
#
# Accuracy :  0.2
# Precison :  0.047058823529411764
# Recall   :  0.2
# F1       :  0.07619047619047618
# Macro F1 :  0.07619047619047618
# MMAE     :  1.55
#
# Confusion matrix (rows = true, cols = predicted)
#       NoAg  GAg  PAg  RAg  Oth
# NoAg     0    3    0    0    1
# GAg      0    4    0    0    0
# PAg      0    3    0    0    1
# RAg      0    3    0    0    1
# Oth      0    4    0    0    0
#
# Saved results   -> /kaggle/working/Replication/Outputs/results_kaggle_smoketest.json
# Saved preds     -> /kaggle/working/Replication/Outputs/predictions_kaggle_smoketest.csv
# Total time : 17.38s

# %% [markdown]
# ## 7. The real run
#
# Paper hyperparameters (Appendix A): batch 4, 20 epochs, lr 5e-5, 16 attention heads, max_len 70.
#
# The best-validation-accuracy checkpoint is kept and used for the test evaluation, as in the original. Mind Kaggle's session time limit (~9–12 hrs) — this run is expected to take 1–2 hrs on a T4.

# %%
# %cd {ROOT}/Scripts
# !python main.py --dataset "{DATASET_PATH}" --captions_suffix _ocr \
    --run_name maf_ocr_mimosa --fix_scheduler \
    --batch_size 16 --n_iter 5 --lrate 5e-5 --heads 16 --max_len 70
# Out:
# /kaggle/working/Replication/Scripts
# Device: cuda:0
# Fetching Dataset...
# -----------------------------
# Maximum Text Length:  70
# Batch Size:  16
# Caption variant: _ocr
# Classes: 5 ['NoAg', 'GAg', 'PAg', 'RAg', 'Oth']
# Training Data: 3393
# Valid Data: 727
# Test Data: 728
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Fetched.
# Time required for preparing the Data loaders: 0.89s
# --------------------------------
# Checkpoint file: /kaggle/working/Replication/Saved_Models/maf_model_maf_ocr_mimosa.pth
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1569.20it/s, Materializing param=
# BertModel LOAD REPORT from: sagorsarker/bangla-bert-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Start Training MAF
# --------------------------------
# Device: cuda:0
# Classes#: 5
# Attention Heads#: 16
# Attention variant: code
# Epochs#: 5
# Learning Rate: 5e-05
# --------------------------------
# Epoch 1/5: 100%|█████| 213/213 [02:33<00:00,  1.39batch/s, acc=0.514, loss=1.17]
# Validation: 100%|████████████████████████████| 46/46 [00:24<00:00,  1.87batch/s]
# Epoch 1/5, Train Loss: 1.1689, Train Acc: 51.44%, Val Acc: 62.31%
# Model Saved.
# Epoch 2/5: 100%|████| 213/213 [02:10<00:00,  1.63batch/s, acc=0.733, loss=0.704]
# Validation: 100%|████████████████████████████| 46/46 [00:18<00:00,  2.48batch/s]
# Epoch 2/5, Train Loss: 0.7041, Train Acc: 73.33%, Val Acc: 70.15%
# Model Saved.
# Epoch 3/5: 100%|████| 213/213 [02:08<00:00,  1.66batch/s, acc=0.863, loss=0.395]
# Validation: 100%|████████████████████████████| 46/46 [00:18<00:00,  2.49batch/s]
# Epoch 3/5, Train Loss: 0.3947, Train Acc: 86.33%, Val Acc: 63.82%
# Epoch 4/5: 100%|██████| 213/213 [02:11<00:00,  1.61batch/s, acc=0.938, loss=0.2]
# Validation: 100%|████████████████████████████| 46/46 [00:18<00:00,  2.54batch/s]
# Epoch 4/5, Train Loss: 0.1998, Train Acc: 93.81%, Val Acc: 62.45%
# Epoch 5/5: 100%|███| 213/213 [02:08<00:00,  1.66batch/s, acc=0.978, loss=0.0904]
# Validation: 100%|████████████████████████████| 46/46 [00:19<00:00,  2.36batch/s]
# Epoch 5/5, Train Loss: 0.0904, Train Acc: 97.80%, Val Acc: 63.27%
# Best Validation Accuracy: 70.15%
# --------------------------------
# Model is Loading.. maf_model_maf_ocr_mimosa.pth
# Loaded.
# --------------------------------
# Start Evaluating..
# Testing: 100%|███████████████████████████████| 46/46 [00:24<00:00,  1.89batch/s]
# Evaluation Done.
# --------------------------------
# Classification Report :
#               precision    recall  f1-score   support
#
#         NoAg      0.597     0.725     0.655       182
#          GAg      0.700     0.729     0.714       144
#          PAg      0.825     0.773     0.798       128
#          RAg      0.863     0.856     0.859       132
#          Oth      0.585     0.437     0.500       142
#
#     accuracy                          0.702       728
#    macro avg      0.714     0.704     0.705       728
# weighted avg      0.703     0.702     0.699       728
#
# Accuracy :  0.7019230769230769
# Precison :  0.703331155970293
# Recall   :  0.7019230769230769
# F1       :  0.69877219160787
# Macro F1 :  0.7054150498097511
# MMAE     :  0.7305720077066908
#
# Confusion matrix (rows = true, cols = predicted)
#       NoAg  GAg  PAg  RAg  Oth
# NoAg   132   22    3    1   24
# GAg     22  105    3    6    8
# PAg     11    5   99    4    9
# RAg     10    2    4  113    3
# Oth     46   16   11    7   62
#
# Saved results   -> /kaggle/working/Replication/Outputs/results_maf_ocr_mimosa.json
# Saved preds     -> /kaggle/working/Replication/Outputs/predictions_maf_ocr_mimosa.csv
# Total time : 806.31s

# %% [markdown]
# ## 8. Ablations and variants (optional)
#
# - `--attn_variant paper` — the attention operand order the **paper text** describes (Q from text, K/V from vision), rather than the order the **released code** implements. See README §5.4.
# - `--fix_scheduler` — steps the LR scheduler per batch instead of per epoch, correcting the original's scheduler bug. See README §5.5.

# %%
# %cd {ROOT}/Scripts
# !python main.py --dataset "{DATASET_PATH}" --run_name maf_paper_attn --attn_variant paper --batch_size 16 --n_iter 5 --lrate 5e-5 --heads 16 --max_len 70
# !python main.py --dataset "{DATASET_PATH}" --run_name maf_fixed_sched --fix_scheduler --batch_size 16 --n_iter 5 --lrate 5e-5 --heads 16 --max_len 70
# Out:
# /kaggle/working/Replication/Scripts
# Device: cuda:0
# Fetching Dataset...
# -----------------------------
# Maximum Text Length:  70
# Batch Size:  16
# Classes: 5 ['NoAg', 'GAg', 'PAg', 'RAg', 'Oth']
# Training Data: 3393
# Valid Data: 727
# Test Data: 728
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Fetched.
# Time required for preparing the Data loaders: 0.90s
# --------------------------------
# Checkpoint file: /kaggle/working/Replication/Saved_Models/maf_model_maf_paper_attn.pth
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1778.16it/s, Materializing param=
# BertModel LOAD REPORT from: sagorsarker/bangla-bert-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Start Training MAF
# --------------------------------
# Device: cuda:0
# Classes#: 5
# Attention Heads#: 16
# Attention variant: paper
# Epochs#: 5
# Learning Rate: 5e-05
# --------------------------------
# Epoch 1/5: 100%|█████| 213/213 [02:11<00:00,  1.62batch/s, acc=0.591, loss=1.02]
# Validation: 100%|████████████████████████████| 46/46 [00:18<00:00,  2.50batch/s]
# Epoch 1/5, Train Loss: 1.0229, Train Acc: 59.10%, Val Acc: 71.11%
# Model Saved.
# Epoch 2/5: 100%|████| 213/213 [02:11<00:00,  1.62batch/s, acc=0.805, loss=0.538]
# Validation: 100%|████████████████████████████| 46/46 [00:19<00:00,  2.41batch/s]
# Epoch 2/5, Train Loss: 0.5382, Train Acc: 80.49%, Val Acc: 70.15%
# Epoch 3/5: 100%|████| 213/213 [02:11<00:00,  1.62batch/s, acc=0.907, loss=0.283]
# Validation: 100%|████████████████████████████| 46/46 [00:18<00:00,  2.50batch/s]
# Epoch 3/5, Train Loss: 0.2835, Train Acc: 90.73%, Val Acc: 69.74%
# Epoch 4/5: 100%|████| 213/213 [02:11<00:00,  1.62batch/s, acc=0.954, loss=0.155]
# Validation: 100%|████████████████████████████| 46/46 [00:19<00:00,  2.34batch/s]
# Epoch 4/5, Train Loss: 0.1553, Train Acc: 95.36%, Val Acc: 69.60%
# Epoch 5/5: 100%|█████| 213/213 [02:17<00:00,  1.55batch/s, acc=0.96, loss=0.117]
# Validation: 100%|████████████████████████████| 46/46 [00:19<00:00,  2.36batch/s]
# Epoch 5/5, Train Loss: 0.1174, Train Acc: 96.04%, Val Acc: 67.40%
# Best Validation Accuracy: 71.11%
# --------------------------------
# Model is Loading.. maf_model_maf_paper_attn.pth
# Loaded.
# --------------------------------
# Start Evaluating..
# Testing: 100%|███████████████████████████████| 46/46 [00:19<00:00,  2.32batch/s]
# Evaluation Done.
# --------------------------------
# Classification Report :
#               precision    recall  f1-score   support
#
#         NoAg      0.595     0.703     0.645       182
#          GAg      0.752     0.590     0.661       144
#          PAg      0.846     0.812     0.829       128
#          RAg      0.909     0.909     0.909       132
#          Oth      0.552     0.563     0.557       142
#
#     accuracy                          0.710       728
#    macro avg      0.731     0.716     0.720       728
# weighted avg      0.719     0.710     0.711       728
#
# Accuracy :  0.7101648351648352
# Precison :  0.718742503166922
# Recall   :  0.7101648351648352
# F1       :  0.7113304890286885
# Macro F1 :  0.7203164657031502
# MMAE     :  0.7241483306404082
#
# Confusion matrix (rows = true, cols = predicted)
#       NoAg  GAg  PAg  RAg  Oth
# NoAg   128   14    7    4   29
# GAg     30   85    2    3   24
# PAg     14    1  104    0    9
# RAg      6    0    3  120    3
# Oth     37   13    7    5   80
#
# Saved results   -> /kaggle/working/Replication/Outputs/results_maf_paper_attn.json
# Saved preds     -> /kaggle/working/Replication/Outputs/predictions_maf_paper_attn.csv
# Total time : 785.17s
# Device: cuda:0
# Fetching Dataset...
# -----------------------------
# Maximum Text Length:  70
# Batch Size:  16
# Classes: 5 ['NoAg', 'GAg', 'PAg', 'RAg', 'Oth']
# Training Data: 3393
# Valid Data: 727
# Test Data: 728
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Fetched.
# Time required for preparing the Data loaders: 0.87s
# --------------------------------
# Checkpoint file: /kaggle/working/Replication/Saved_Models/maf_model_maf_fixed_sched.pth
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1557.34it/s, Materializing param=
# BertModel LOAD REPORT from: sagorsarker/bangla-bert-base
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Start Training MAF
# --------------------------------
# Device: cuda:0
# Classes#: 5
# Attention Heads#: 16
# Attention variant: code
# Epochs#: 5
# Learning Rate: 5e-05
# --------------------------------
# Epoch 1/5: 100%|█████| 213/213 [02:11<00:00,  1.62batch/s, acc=0.587, loss=1.02]
# Validation: 100%|████████████████████████████| 46/46 [00:19<00:00,  2.33batch/s]
# Epoch 1/5, Train Loss: 1.0235, Train Acc: 58.66%, Val Acc: 70.56%
# Model Saved.
# Epoch 2/5: 100%|████| 213/213 [02:11<00:00,  1.62batch/s, acc=0.807, loss=0.526]
# Validation: 100%|████████████████████████████| 46/46 [00:18<00:00,  2.46batch/s]
# Epoch 2/5, Train Loss: 0.5256, Train Acc: 80.66%, Val Acc: 69.74%
# Epoch 3/5: 100%|████| 213/213 [02:09<00:00,  1.64batch/s, acc=0.928, loss=0.237]
# Validation: 100%|████████████████████████████| 46/46 [00:19<00:00,  2.41batch/s]
# Epoch 3/5, Train Loss: 0.2369, Train Acc: 92.78%, Val Acc: 68.91%
# Epoch 4/5: 100%|██████| 213/213 [02:10<00:00,  1.63batch/s, acc=0.974, loss=0.1]
# Validation: 100%|████████████████████████████| 46/46 [00:18<00:00,  2.43batch/s]
# Epoch 4/5, Train Loss: 0.1002, Train Acc: 97.45%, Val Acc: 69.19%
# Epoch 5/5: 100%|████| 213/213 [02:10<00:00,  1.63batch/s, acc=0.99, loss=0.0482]
# Validation: 100%|████████████████████████████| 46/46 [00:19<00:00,  2.37batch/s]
# Epoch 5/5, Train Loss: 0.0482, Train Acc: 99.03%, Val Acc: 69.60%
# Best Validation Accuracy: 70.56%
# --------------------------------
# Model is Loading.. maf_model_maf_fixed_sched.pth
# Loaded.
# --------------------------------
# Start Evaluating..
# Testing: 100%|███████████████████████████████| 46/46 [00:19<00:00,  2.33batch/s]
# Evaluation Done.
# --------------------------------
# Classification Report :
#               precision    recall  f1-score   support
#
#         NoAg      0.621     0.665     0.642       182
#          GAg      0.727     0.611     0.664       144
#          PAg      0.871     0.789     0.828       128
#          RAg      0.910     0.924     0.917       132
#          Oth      0.549     0.627     0.586       142
#
#     accuracy                          0.716       728
#    macro avg      0.736     0.723     0.727       728
# weighted avg      0.724     0.716     0.718       728
#
# Accuracy :  0.7156593406593407
# Precison :  0.7243136429660705
# Recall   :  0.7156593406593407
# F1       :  0.7179395312908375
# Macro F1 :  0.7273498318102062
# MMAE     :  0.7015713599780501
#
# Confusion matrix (rows = true, cols = predicted)
#       NoAg  GAg  PAg  RAg  Oth
# NoAg   121   20    6    3   32
# GAg     25   88    2    3   26
# PAg     13    0  101    0   14
# RAg      7    1    1  122    1
# Oth     29   12    6    6   89
#
# Saved results   -> /kaggle/working/Replication/Outputs/results_maf_fixed_sched.json
# Saved preds     -> /kaggle/working/Replication/Outputs/predictions_maf_fixed_sched.csv
# Total time : 776.86s

# %% [markdown]
# ## 9. Results
#
# Compares every run in `Outputs/` against both papers' published rows.
#
# **This is now a like-for-like reproduction.** The corpus is the full five-way MIMOSA that
# MAF was published on, and the captions are the dataset authors' own hand-corrected text, so
# the published MAF row is a real target rather than a loose reference. That was not true of
# the earlier four-class OCR'd corpus, where the gap was dominated by caption noise.
#
# MuLAD runs, if present, are listed separately - see README §7.

# %%
import glob, json
import pandas as pd

rows = []
for path in sorted(glob.glob(f'{ROOT}/Outputs/results_*.json')):
    r = json.load(open(path, encoding='utf-8'))
    if r.get('hyperparameters', {}).get('subset'):
        continue                                  # smoke tests are not results
    rows.append({
        'run': r['run_name'],
        'framework': r.get('framework', 'MAF'),
        'Acc': round(r['accuracy'], 3),
        'WF1': round(r['weighted_f1'], 3),
        'MacroF1': round(r['macro_f1'], 3),
        'MMAE': round(r['mmae'], 3),
    })

table = pd.DataFrame(rows).sort_values('WF1', ascending=False)
for fw in table['framework'].unique():
    print(f'--- {fw} ---')
    print(table[table['framework'] == fw].drop(columns='framework').to_string(index=False))
    print()

print('Published reference points')
print('  MAF   (Ahsan et al. 2024, 5-way MIMOSA) : Acc 0.741  WF1 0.742  MMAE 0.645  <- like-for-like')
print('  MuLAD (Hasan et al., BINARY AMemD)      : Acc 0.778  WF1 0.738   (different task and corpus)')
# Out:
# --- MAF ---
#             run   Acc   WF1  MacroF1  MMAE
# maf_fixed_sched 0.716 0.718    0.727 0.702
#  maf_paper_attn 0.710 0.711    0.720 0.724
#  maf_ocr_mimosa 0.702 0.699    0.705 0.731
#
# Published reference points
#   MAF   (Ahsan et al. 2024, 5-way MIMOSA) : Acc 0.741  WF1 0.742  MMAE 0.645  <- like-for-like
#   MuLAD (Hasan et al., BINARY AMemD)      : Acc 0.778  WF1 0.738   (different task and corpus)

# %% [markdown]
# ## 10. Confusion matrix

# %%
import json
import matplotlib.pyplot as plt
import seaborn as sns

RUN = 'maf_full'
r = json.load(open(f'{ROOT}/Outputs/results_{RUN}.json', encoding='utf-8'))

plt.figure(figsize=(5.5, 4.5))
sns.heatmap(r['confusion_matrix'], annot=True, fmt='d', cmap='Blues',
            xticklabels=r['target_names'], yticklabels=r['target_names'], cbar=False)
plt.xlabel('Predicted'); plt.ylabel('True'); plt.title(f'MAF — {RUN}')
plt.tight_layout(); plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23/249068503.py in <cell line: 0>()
#       4
#       5 RUN = 'maf_full'
# ----> 6 r = json.load(open(f'{ROOT}/Outputs/results_{RUN}.json', encoding='utf-8'))
#       7
#       8 plt.figure(figsize=(5.5, 4.5))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/Replication/Outputs/results_maf_full.json'

# %% [markdown]
# ## 11. Results persist automatically
#
# Everything under `/kaggle/working` (including `{ROOT}/Outputs` and `{ROOT}/Saved_Models`) is kept as the notebook's **Output** when you commit/save the session — download it from the notebook's "Output" tab afterward. No extra copy step needed (unlike Colab, which needs an explicit copy back to Drive).

# %%
# !ls -lh {ROOT}/Outputs {ROOT}/Saved_Models
